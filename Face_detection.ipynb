# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashokmani1/Machine-Learning/blob/master/Face_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install face_recognition

# %%
import numpy as np
import cv2
import face_recognition
from PIL import Image
import matplotlib.pyplot as plt

# %%
ls
# Out:
# IMG-20181219-WA0015.jpg  IMG-20190114-WA0008.jpg
# IMG-20190114-WA0006.jpg  sample_data/

# %%
image = face_recognition.load_image_file("IMG-20181219-WA0015.jpg")
plt.imshow(image)
plt.show()

# %%
face_locations = face_recognition.face_locations(image,model = 'cnn')
face_locations
# Out:
# [(484, 757, 566, 675),
#  (113, 363, 358, 119),
#  (152, 1105, 234, 1023),
#  (28, 610, 96, 541),
#  (123, 830, 180, 773)]

# %%
for face_location in face_locations:
  top,right,bottom,left = face_location
  img  = cv2.rectangle(image,(left,top),(right,bottom),(0,0,256),5)
plt.imshow(img)
plt.show()

# %%
face_locations
# Out:
# [(484, 757, 566, 675),
#  (113, 363, 358, 119),
#  (152, 1105, 234, 1023),
#  (28, 610, 96, 541),
#  (123, 830, 180, 773)]

# %%
for face_location in face_locations:
  top,right,bottom,left = face_location
  face_image = image[top:bottom,left:right]
  pil_image = Image.fromarray(face_image)
  plt.imshow(pil_image)
  plt.show()
